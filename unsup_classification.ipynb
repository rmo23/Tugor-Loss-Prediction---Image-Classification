# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import os

# %% [markdown]
# Convert the unlabeled data to .npy file

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import cv2
import numpy as np
import os
from PIL import Image

data_folder = "/content/drive/My Drive/NN-ProjectC/Project_C1/Training/unlabeled_data"
dataset = np.ndarray(shape=(len(os.listdir(data_folder)), 3, 224, 224),
                     dtype=np.float32)

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# dataset_train = []
i = 0
for f in os.listdir(data_folder):
        try:
          # img = cv2.imread(data_folder + "/" + f, cv2.IMREAD_COLOR)
          img = load_img(data_folder + "/" + f)  # this is a PIL image
          # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
          # img_resize = cv2.resize(img,(128,128))
          # print (img_resize.shape)
          
        except:
          print ("Exception")
          continue
        
        img = img.resize((224, 224), Image.ANTIALIAS)
        x = img_to_array(img)  
        # print (x)
        # x = x.resize((3,224,224))
        # print (x)
        # x = rgb2gray(x)
        # print (x.shape)
        # np.asarray(vector).reshape(shape)
        x = np.asarray(x).reshape(3,224, 224)
        # print (x.shape)

        # img.thumbnail((480, 640))
        # x = x.resize(1, 224, 224)
        # print (x)
        # break
        dataset[i] = x
        i += 1
        if i % 250 == 0:
            print("%d images to array" % i)

# img_data = np.array(dataset_train)
# img_data = img_data.astype('float32')
# img_data /=255
print(dataset.shape)
print("All images to array!")
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 250 images to array
# 500 images to array
# 750 images to array
# 1000 images to array
# Exception
# Exception
# Exception
# Exception
# 1250 images to array
# Exception
# Exception
# Exception
# Exception
# 1500 images to array
# 1750 images to array
# Exception
# Exception
# Exception
# 2000 images to array
# Exception
# Exception
# 2250 images to array
# Exception
# 2500 images to array
# Exception
# Exception
# Exception
# Exception
# 2750 images to array
# Exception
# Exception
# 3000 images to array
# ...

# %%
print (dataset[300])
np.save('/content/drive/My Drive/NN-ProjectC/Project_C1/Training/data_unlabeled.npy', dataset)
# Out:
# [[[217. 206. 189. ... 164. 178. 192.]
#   [147. 185. 193. ... 255. 241. 255.]
#   [253. 241. 246. ... 254. 255. 252.]
#   ...
#   [186. 157. 175. ...  75.  80.  55.]
#   [ 71.  70.  61. ...  73. 123. 129.]
#   [ 97. 128. 137. ... 187. 157. 169.]]
#
#  [[188. 159. 168. ...  75.  78.  51.]
#   [ 76.  82.  70. ...  65. 134. 142.]
#   [110. 137. 145. ... 191. 163. 152.]
#   ...
#   [ 61.  80.  92. ... 138.  67. 106.]
#   [119.  53.  86. ... 111. 120.  65.]
#   [ 65.  75.  54. ...  65.  85.  98.]]
#
#  [[ 63.  88. 101. ... 133.  66. 119.]
#   [139.  55.  93. ... 109. 121.  57.]
#   [ 64.  74.  54. ...  64.  90. 101.]
#   ...
#   [ 26.  29.  16. ...  64. 101. 120.]
#   [ 77.  86. 100. ... 122.  75. 102.]
#   [123.  75. 112. ... 166. 182. 166.]]]

# %% [markdown]
# Creating .npy file for training images

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import cv2
import numpy as np
import os
from PIL import Image

data_folder = "/content/drive/My Drive/NN-ProjectC/Project_C1/Training/augmented_images"
dataset_train = np.ndarray(shape=(1868, 3, 224, 224),
                     dtype=np.float32)

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# dataset_train = []
i = 0
for folder in os.listdir(data_folder):
    sub_folder = os.path.join(data_folder, folder)
    for f in os.listdir(sub_folder):
      if not f.startswith("."): 
        try:
          # img = cv2.imread(data_folder + "/" + f, cv2.IMREAD_COLOR)
          img = load_img(sub_folder + "/" + f)  # this is a PIL image
          # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
          # img_resize = cv2.resize(img,(128,128))
          # print (img_resize.shape)
          
        except:
          print ("Exception")
          continue
        
        img = img.resize((224, 224), Image.ANTIALIAS)
        x = img_to_array(img)  
        # print (x)
        # x = x.resize((3,224,224))
        # print (x)
        # x = rgb2gray(x)
        # print (x.shape)
        # np.asarray(vector).reshape(shape)
        x = np.asarray(x).reshape(3,224, 224)
        # print (x.shape)

        # img.thumbnail((480, 640))
        # x = x.resize(1, 224, 224)
        # print (x)
        # break
        dataset_train[i] = x
        i += 1
        if i % 250 == 0:
            print("%d images to array" % i)

# img_data = np.array(dataset_train)
# img_data = img_data.astype('float32')
# img_data /=255
print(dataset_train.shape)
print("All images to array!")
# Out:
# (1868, 3, 224, 224)
# All images to array!

# %%
# print (dataset_train[0])
np.save('/content/drive/My Drive/NN-ProjectC/Project_C1/Training/data_labeled_color.npy', dataset_train)

# %%
# Now get the labels for these images
data_folder = "/content/drive/My Drive/NN-ProjectC/Project_C1/Training/augmented_images"
dataset_train = np.ndarray(shape=(1868, 1), dtype=np.int)
i = 0
for folder in os.listdir(data_folder):
    sub_folder = os.path.join(data_folder, folder)
    for f in os.listdir(sub_folder):
      if not f.startswith("."):
        dataset_train[i] = folder
        i += 1

print(dataset_train.shape)
print (dataset_train)
# Out:
# (1868, 1)
# [[0]
#  [0]
#  [0]
#  ...
#  [4]
#  [4]
#  [4]]

# %%
np.save('/content/drive/My Drive/NN-ProjectC/Project_C1/Training/data_labeled_labels.npy', dataset_train)

# %% [markdown]
# Load the data and split into train and validation

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import os

dataset1 = np.load('/content/drive/My Drive/NN-ProjectC/Project_C1/Training/data_labeled_color.npy', allow_pickle=True)
dataset1 = np.reshape(dataset1, (len(dataset1), 224, 224, 3))
dataset1 /=255
print (dataset1.shape)
Y = np.load('/content/drive/My Drive/NN-ProjectC/Project_C1/Training/data_labeled_labels.npy', allow_pickle=True)
print (Y.shape)
train_x, val_x, y_train, y_test = train_test_split(dataset1, Y, test_size=0.3, random_state=33)
# Out:
# (1868, 224, 224, 3)
# (1868, 1)

# %%
print (y_train)
# Out:
# [[2]
#  [0]
#  [3]
#  ...
#  [4]
#  [0]
#  [2]]

# %% [markdown]
# The Model for the Autoencoder

# %%
num_class = 5
from keras import optimizers
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, Dense, Activation, Lambda, Reshape, Flatten
from keras.models import Model
from keras import backend as K

# Custom classifier function:
def classifier_func(x):
    return x+x*K.one_hot(K.argmax(x, axis=1), num_classes=num_class)

inputs = Input(shape=(224, 224, 3))
#Encoder:
conv_1 = Conv2D(32, (3,3), strides=(1,1))(inputs)
act_1 = Activation('relu')(conv_1)
maxpool_1 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(act_1)

conv_2 = Conv2D(64, (3,3), strides=(1,1), padding='same')(maxpool_1)
act_2 = Activation('relu')(conv_2)
maxpool_2 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(act_2)

# conv_3 = Conv2D(64, (3,3), strides=(1,1), padding='same')(maxpool_2)
# act_3 = Activation('relu')(conv_3)
# maxpool_3 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(act_3)
# Output Shape: 6x6x64
    
flat_1 = Flatten()(maxpool_2)

fc_1 = Dense(256)(flat_1)
act_3 = Activation('relu')(fc_1)

fc_2 = Dense(128)(act_3)
act_4 = Activation('relu')(fc_2)

fc_3 = Dense(num_class)(act_4)

act_class = Lambda(classifier_func, output_shape=(num_class,))(fc_3)
# Output Shape: 5

#Decoder:
fc_4 = Dense(128)(act_class)
act_5 = Activation('relu')(fc_4)

fc_5 = Dense(256)(act_5)
act_6 = Activation('relu')(fc_5)

fc_6 = Dense(193600)(act_6)
act_7 = Activation('relu')(fc_6)

# fc_7 = Dense(46656)(act_7)
# act_8 = Activation('relu')(fc_7)

reshape_1 = Reshape((55,55,64))(act_7)

# upsample_0 = UpSampling2D((2, 2))(reshape_1)
# deconv_0 = Conv2DTranspose(64, (3, 3), strides=(1, 1))(upsample_0)
# act_17 = Activation('relu')(deconv_0)

upsample_1 = UpSampling2D((2, 2))(reshape_1)
deconv_1 = Conv2DTranspose(32, (3, 3), strides=(1, 1))(upsample_1)
act_7 = Activation('relu')(deconv_1)

upsample_2 = UpSampling2D((2, 2))(act_7)
deconv_2 = Conv2DTranspose(32, (3, 3), strides=(1, 1))(upsample_2)
act_8 = Activation('relu')(deconv_2)

conv_3 = Conv2D(3, (3, 3), strides=(1, 1))(act_8)
act_9 = Activation('sigmoid')(conv_3)
# Output Shape: 28x28x1

autoencoder = Model(inputs, act_9)
adadelta = optimizers.Adam(lr=0.001)
autoencoder.compile(optimizer=adadelta, loss='mean_squared_error', metrics = ['mean_squared_error'])

autoencoder.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# ...

# %%
# Checkpoints:
from keras.callbacks import ModelCheckpoint, TensorBoard
checkpoints = []
#checkpoints.append(TensorBoard(log_dir='/Checkpoints/logs'))
# Training Model:
epochs = 100
batch_size = 64
autoencoder.fit(train_x, train_x, batch_size=batch_size, epochs=epochs, 
                validation_data=(val_x, val_x), shuffle=True, callbacks=checkpoints)
autoencoder.save("Labeled_colour_autoencoder1.h5")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1307 samples, validate on 561 samples
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
dataset1 = np.reshape(dataset1, (len(dataset1), 224, 224, 3))
# dataset /=255
decoded_imgs = autoencoder.predict(dataset1[50:55])
# decoded_imgs = decoded_imgs.reshape(224, 224)

# %%
import matplotlib.pyplot as plt
plt.imshow(decoded_imgs[0])

# %%
# Split autoencoder:
encoder = Model(inputs, act_class)
encoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# activation_1 (Activation)    (None, 222, 222, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 111, 111, 64)      18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 111, 111, 64)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 55, 55, 64)        0
# ...

# %%
print (train_x)

# %%
encode = encoder.predict(val_x)
print (len(y_train))
# for i in range(1307):
#   print (np.argmax(encode[i]))
class_dict = np.zeros((num_class, num_class))
for i, sample in enumerate(y_test):
    # print (sample, np.argmax(encode[i]))
    class_dict[np.argmax(encode[i])][sample] += 1


print(class_dict)
    
neuron_class = np.zeros((num_class))
for i in range(num_class):
    neuron_class[i] = np.argmax(class_dict[i], axis=0)

print(neuron_class)
# Out:
# 1307
# [[ 4.  1.  7.  1. 25.]
#  [34. 42. 38. 33. 24.]
#  [31. 19. 17. 12.  0.]
#  [ 3.  4.  5. 10. 56.]
#  [68. 44. 29. 43. 11.]]
# [4. 1. 0. 4. 0.]

# %%
from sklearn.metrics import accuracy_score
y_pred = np.array([np.argmax(encode[i]) for i in range(len(y_test))])
accuracy_score(y_test, y_pred, normalize=False)
# y_pred
# Out:
# 84

# %%
from sklearn.metrics import confusion_matrix

labels = [0,1,2,3,4]
cm = confusion_matrix(y_test, y_pred, labels)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
#plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# [[ 4 34 31  3 68]
#  [ 1 42 19  4 44]
#  [ 7 38 17  5 29]
#  [ 1 33 12 10 43]
#  [25 24  0 56 11]]

# %%
encode = encoder.predict(val_x)

predicted = np.argmax(encode, axis=1)
for i, sample in enumerate(predicted):
    predicted[i] = neuron_class[predicted[i]]

comparison = y_test == predicted
loss = 1 - np.sum(comparison.astype(int))/y_test.shape[0]

print('Loss:', loss)
print('Examples:')
for i in range(10):
    plt.imshow(val_x[i].reshape(224, 224, 3))
    plt.axis('off')
    plt.show()
    neuron = np.argmax(encode[i], axis=0)
    print('Class:', y_test[i], '- Model\'s Output Class:', neuron_class[neuron])
# Out:
# Loss: -128.88235294117646
# Examples:
# Class: [0] - Model's Output Class: 0.0
# Class: [4] - Model's Output Class: 4.0
# Class: [4] - Model's Output Class: 0.0
# Class: [0] - Model's Output Class: 0.0
# Class: [0] - Model's Output Class: 0.0
# Class: [3] - Model's Output Class: 1.0
# Class: [2] - Model's Output Class: 0.0
# Class: [3] - Model's Output Class: 0.0
# Class: [2] - Model's Output Class: 1.0
# Class: [0] - Model's Output Class: 0.0

# %%
import matplotlib.pyplot as plt

n = 5
plt.figure(figsize=(20, 4))
for i in range(1, n):
    # display original
    ax = plt.subplot(2, n, i)
    plt.imshow(np.squeeze(dataset[i]))
    # plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(np.squeeze(decoded_imgs[i]))
    # plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

# %%
n_clusters = 5
dims = [1307, 500, 500, 2000, 10]
init = VarianceScaling(scale=1. / 3., mode='fan_in',
                           distribution='uniform')
pretrain_optimizer = SGD(lr=1, momentum=0.9)
pretrain_epochs = 300
batch_size = 256
save_dir = ''

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/keras/engine/base_layer.py in assert_input_compatibility(self, inputs)
#     272             try:
# --> 273                 K.is_keras_tensor(x)
#     274             except ValueError:
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in is_keras_tensor(x)
#     497         raise ValueError('Unexpectedly found an instance of type `' +
# --> 498                          str(type(x)) + '`. '
#     499                          'Expected a symbolic tensor instance.')
#
# ValueError: Unexpectedly found an instance of type `<class 'int'>`. Expected a symbolic tensor instance.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-528fe2bb77e8> in <module>()
#       1 autoencoder.compile(optimizer=pretrain_optimizer, loss='mse')
# ----> 2 autoencoder.fit(x, x, batch_size=batch_size, epochs=pretrain_epochs) #, callbacks=cb)
#       3 autoencoder.save_weights(save_dir + 'ae_weights.h5')
#
# NameError: name 'x' is not defined

# %%
autoencoder.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
estop = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='auto')

# %%
train_history = autoencoder.fit(train_x, train_x, epochs=500, batch_size=2048, validation_data=(val_x, val_x), callbacks=[estop])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 802368 samples, validate on 343872 samples
# Epoch 1/500
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
from keras.datasets import fashion_mnist
(train_x, train_y), (val_x, val_y) = fashion_mnist.load_data()
print (train_x.shape)
train_x = train_x/255.
val_x = val_x/255.

train_x = train_x.reshape(-1, 784)
val_x = val_x.reshape(-1, 784)
train_x.shape
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# (60000, 28, 28)
# (60000, 784)
